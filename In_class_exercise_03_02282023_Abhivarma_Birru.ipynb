# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhivarma-Birru-Unt/Abhivarma_INFO5731_Spring2023/blob/main/In_class_exercise_03_02282023_Abhivarma_Birru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (2/28/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
The text classification method which we would discuss over here is kind of extracting using google colab from the text we have used in sampleData.txt file based on the previous assignments data extraction
The feautures which might be helpfull in extracting is
Number of sentences, Number of words, Number of characters, Average word length, Number of special characters, 
Number of numerics,Number of uppercase words.
Number of sentences = Tells us about how many snetences are present in the list
Number of words = Tells us about the how many words are present in the list
Number of characters = how many characters are present in the list
Average word length = Tells us about how many  average of words that are present in the list
Number of special characters = Tells us about how many number of special characters that are present in the list
This features are helpful in organising the data and using them for the appropriate methods.



'''
# Out:
# '\nPlease write you answer here:\nThe text classification method which we would discuss over here is kind of extracting using google colab from the text we have used in sampleData.txt file based on the previous assignments data extraction\nThe feautures which might be helpfull in extracting is\nNumber of sentences, Number of words, Number of characters, Average word length, Number of special characters, \nNumber of numerics,Number of uppercase words.\nNumber of sentences = Tells us about how many snetences are present in the list\nNumber of words = Tells us about the how many words are present in the list\nNumber of characters = how many characters are present in the list\nAverage word length = Tells us about how many  average of words that are present in the list\nNumber of special characters = Tells us about how many number of special characters that are present in the list\nThis features are helpful in organising the data and using them for the appropriate methods.\n\n\n\n'

# %% [markdown]
# Question 2 (10 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
# You code here (Please add comments in the code):
from six.moves import urllib
import pandas as pd 
txtList = []
urlForText = "https://raw.githubusercontent.com/Abhivarma-Birru-Unt/Abhivarma_INFO5731_Spring2023/main/sampledata.txt"
txtFile = urllib.request.urlopen(urlForText)  #Here we use the url and get the data from it it is a predefined function
for i in txtFile:
    decoded_data = i.decode("utf-8").replace('\r\n', '')    #Here we  decode the data present in the url and convert it into standard format
    if decoded_data: 
        txtList.append(decoded_data)       #append the decoded data to a list
txtDataFrame = pd.DataFrame (txtList, columns = ['Text'])   #converting the list to data frame using pamdas
print(txtDataFrame)
# Out:
#                                                   Text
# 0                   Synonyms of about (Entry 1 of 3)\n
# 1                                 1having to do with\n
# 2    a POIGANT story about a young man who goes off...
# 3                                 Synonyms for about\n
# 4                                                   \n
# ..                                                 ...
# 117                                                 \n
# 118  asleep, dormant, dozing, napping, resting, sle...
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...
# 120                                      dreaming ME\n
# 121                           hypnotized, MESMERIZED\n
#
# [122 rows x 1 columns]

# %%
#To find Number of Sentences in a data frame

txtDataFrame['Number of sentences'] = txtDataFrame['Text'].apply(lambda y: len(str(y).split(".")))
txtDataFrame
# Out:
#                                                   Text  Number of sentences
# 0                   Synonyms of about (Entry 1 of 3)\n                    1
# 1                                 1having to do with\n                    1
# 2    a POIGANT story about a young man who goes off...                    1
# 3                                 Synonyms for about\n                    1
# 4                                                   \n                    1
# ..                                                 ...                  ...
# 117                                                 \n                    1
# 118  asleep, dormant, dozing, napping, resting, sle...                    1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                    1
# 120                                      dreaming ME\n                    1
# 121                           hypnotized, MESMERIZED\n                    1
#
# [122 rows x 2 columns]

# %%
#To find Number of words in a data frame

txtDataFrame['Number of Words'] = txtDataFrame['Text'].apply(lambda y: len(str(y).split(" ")))
txtDataFrame
# Out:
#                                                   Text  Number of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                    1
# 1                                 1having to do with\n                    1
# 2    a POIGANT story about a young man who goes off...                    1
# 3                                 Synonyms for about\n                    1
# 4                                                   \n                    1
# ..                                                 ...                  ...
# 117                                                 \n                    1
# 118  asleep, dormant, dozing, napping, resting, sle...                    1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                    1
# 120                                      dreaming ME\n                    1
# 121                           hypnotized, MESMERIZED\n                    1
#
#      Number of Words
# 0                  7
# ...

# %%
#To find Number of characters in data frame

txtDataFrame['Number of Characters'] = txtDataFrame['Text'].str.len()
txtDataFrame
# Out:
#                                                   Text  Number of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                    1
# 1                                 1having to do with\n                    1
# 2    a POIGANT story about a young man who goes off...                    1
# 3                                 Synonyms for about\n                    1
# 4                                                   \n                    1
# ..                                                 ...                  ...
# 117                                                 \n                    1
# 118  asleep, dormant, dozing, napping, resting, sle...                    1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                    1
# 120                                      dreaming ME\n                    1
# 121                           hypnotized, MESMERIZED\n                    1
#
#      Number of Words  Number of Characters
# ...

# %%
#To find the average word length of the list


def avgWordLength(x):
    wordList = x.split() #here the sentence is being splitted into parts and being assigned to variable wordList
    if len(wordList) != 0:  #here we are checking if the variable is empty or not
        return(sum(len(deep) for deep in wordList)/len(wordList))
    else:
        return None

txtDataFrame['Avg Word Length'] = txtDataFrame['Text'].apply(lambda z: avgWordLength(z))
txtDataFrame
# Out:
#                                                   Text  Number of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                    1
# 1                                 1having to do with\n                    1
# 2    a POIGANT story about a young man who goes off...                    1
# 3                                 Synonyms for about\n                    1
# 4                                                   \n                    1
# ..                                                 ...                  ...
# 117                                                 \n                    1
# 118  asleep, dormant, dozing, napping, resting, sle...                    1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                    1
# 120                                      dreaming ME\n                    1
# 121                           hypnotized, MESMERIZED\n                    1
#
# ...

# %%
#To find the number of special characters present in the list

def specialCharacters(x):
    read = 0
    for i in range(len(x)):
        if not((x[i].isalpha()) and (x[i].isdigit())):
            read = read + 1
    return read

txtDataFrame['Number of special characters'] = txtDataFrame['Text'].apply(lambda z: specialCharacters(z))
txtDataFrame
# Out:
#                                                   Text  Number of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                    1
# 1                                 1having to do with\n                    1
# 2    a POIGANT story about a young man who goes off...                    1
# 3                                 Synonyms for about\n                    1
# 4                                                   \n                    1
# ..                                                 ...                  ...
# 117                                                 \n                    1
# 118  asleep, dormant, dozing, napping, resting, sle...                    1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                    1
# 120                                      dreaming ME\n                    1
# 121                           hypnotized, MESMERIZED\n                    1
#
# ...

# %%
#To find the number of numerics present in the list

txtDataFrame['Number of number'] = txtDataFrame['Text'].apply(lambda x: len([x for x in x.split() if x.isdigit()])) #here we are considering it to be a seperate numeric if it is seperated with a space using the split function
txtDataFrame
# Out:
#                                                   Text  Number of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                    1
# 1                                 1having to do with\n                    1
# 2    a POIGANT story about a young man who goes off...                    1
# 3                                 Synonyms for about\n                    1
# 4                                                   \n                    1
# ..                                                 ...                  ...
# 117                                                 \n                    1
# 118  asleep, dormant, dozing, napping, resting, sle...                    1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                    1
# 120                                      dreaming ME\n                    1
# 121                           hypnotized, MESMERIZED\n                    1
#
# ...

# %%
#To find number of uppercase words in a list

txtDataFrame['Number of upper case words'] = txtDataFrame['Text'].apply(lambda x: len([x for x in x.split() if x.isupper()])) #using split function we are finding the words with completely upper case
txtDataFrame
# Out:
#                                                   Text  Number of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                    1
# 1                                 1having to do with\n                    1
# 2    a POIGANT story about a young man who goes off...                    1
# 3                                 Synonyms for about\n                    1
# 4                                                   \n                    1
# ..                                                 ...                  ...
# 117                                                 \n                    1
# 118  asleep, dormant, dozing, napping, resting, sle...                    1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                    1
# 120                                      dreaming ME\n                    1
# 121                           hypnotized, MESMERIZED\n                    1
#
# ...

# %%
txtDataFrame.to_csv('data.csv',index=True)

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)." Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
# You code here (Please add comments in the code):
''' Rank of most important features here:
1. Number of sentences
2. Number of Words
3. Number of Characters
4. Stowords
5. Lowercase
6. Removal of Punctuation '''

text_classifcation = (txtDataFrame['Text'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
text_classifcation.columns =['words', 'tf']
text_classifcation
# Out:
#      words  tf
# 0  1having   1
# 1       to   1
# 2       do   1
# 3   with\n   1

# %%
import numpy as np 

for i,word in enumerate(text_classifcation['words']):
  text_classifcation.loc[i, 'idf'] = np.log(txtDataFrame.shape[0]/(len(txtDataFrame[txtDataFrame['Text'].str.contains(word)])))

text_classifcation
# Out:
#      words  tf       idf
# 0  1having   1  4.804021
# 1       to   1  1.248673
# 2       do   1  2.858111
# 3   with\n   1  4.804021

# %%
text_classifcation['tfidf'] = text_classifcation['tf'] + text_classifcation['idf']
text_classifcation
# Out:
#      words  tf       idf     tfidf
# 0  1having   1  4.804021  5.804021
# 1       to   1  1.248673  2.248673
# 2       do   1  2.858111  3.858111
# 3   with\n   1  4.804021  5.804021

# %% [markdown]
# Question 4 (10 points): Write python code to rank the text based on text similarity. Based on the text data you used for question 2, design a query to match the most relevant docments. Please use the BERT model to represent both your query and the text data, then calculate the cosine similarity between the query and each text in your data. Rank the similary with descending order.

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# You code here (Please add comments in the code):

import torch
from transformers import BertTokenizer, BertModel

txtDataFrame2 = txtDataFrame[txtDataFrame['Text']!="\n"]
txtList2 = txtDataFrame2['Text'].values
print(txtList2)


tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased',
                                  output_hidden_states = True,
                                  )



query = 'Near Antonyms for about'

query_tokens = tokenizer.tokenize(query)
query_encoded = tokenizer.encode(query_tokens,
                                 padding = 'max_length',
                                 max_length = 30,
                                 truncation = True,
                                 )

txt_tokens = [tokenizer.tokenize(text) for text in txtList2]
txt_encoded = [tokenizer.encode(txt_token,
                                 padding = 'max_length',
                                 max_length = 30,
                                 truncation = True,
                                 ) for txt_token in txt_tokens
                                 ]

query_output = model(query_encoded)[2][-2].squeeze(0)
text_output = [model(text_enc)[2][-2].squeeze(0) for text_enc in txt_encoded]

similarities = [torch.cosine_similarity(query_output, text_output, dim=0)]
# Out:
# ['Synonyms of about (Entry 1 of 3)\n' '1having to do with\n'
#  'a POIGANT story about a young man who goes off to war\n'
#  'Synonyms for about\n'
#  'apropos, apropos of, as far as, as for, as regards (also as respects), as to, concerning, of, on, regarding, respecting, touching, toward (or towards)\n'
#  'Words Related to about\n' 'over\n' 'Phrases SYNONYMOUS with about\n'
#  'in regard to, in respect to, in view of, with regard to, with respect to\n'
#  '2close to\n' 'about the hedge there was a picket fence\n'
#  'Synonyms for about\n' 'around, by, near, next to, nigh\n'
#  'Words Related to about\n' 'alongside, beside\n' 'across, along, at\n'
#  'circa\n' 'toward (or towards)\n' 'Phrases Synonymous with about\n'
#  'next door to\n' '3in random positions within the boundaries of\n'
#  'sparrows hopping about the lawn near the bird feeder\n'
#  'Synonyms for about\n'
#  'across, around, over, round, through, throughout\n'
#  'Words Related to about\n' 'on\n' 'about adverb\n'
# ...
